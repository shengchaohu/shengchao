# %%
import visual
from imp import reload

# %%
reload(visual)
# Out:
# <module 'visual' from '/Users/hushengchao/Desktop/实习相关/webcam/visual.py'>

# %%
visual.printout()
# Out:
# These basic info about the question and student are provided:
# ['cost_time' 'course_id' 'difficulty' 'is_right' 'question_end_time'
#  'question_end_time_delta' 'question_id' 'question_start_time'
#  'question_start_time_delta' 'right_answer' 'school_id' 'section_id'
#  'subject' 'topic_id']
#
# Figures below shows relations between correctness and some of these info
#
# In the below scatter plots, Red point means correctness, Blue point means incorrectness
# For the next 34 figures, each shows the possible relation between correctness and course for a student (there are 34 students in total in the dataset)
# In the below scatter plots, Red point means correctness, Blue point means incorrectness
# For the next 34 figures, each shows the possible relation between correctness and difficulty for a student (there are 34 students in total in the dataset)
# In the below scatter plots, Red point means correctness, Blue point means incorrectness
# ...
